# %%
pip install langchain langchain-google-genai fastapi uvicorn
# Out:
# Requirement already satisfied: langchain in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (1.3.4)
# Requirement already satisfied: langchain-google-genai in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (4.2.4)
# Collecting fastapi
#   Obtaining dependency information for fastapi from https://files.pythonhosted.org/packages/6c/ff/8496d9847a5fedae775eb49460722d3efaa80487854273e9647ae876218c/fastapi-0.138.0-py3-none-any.whl.metadata
#   Downloading fastapi-0.138.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: uvicorn in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (0.49.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.4 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain) (2.13.4)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain-google-genai) (2.7.0)
# Requirement already satisfied: starlette>=0.46.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from fastapi) (1.2.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from fastapi) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: click>=7.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from uvicorn) (8.4.1)
# Requirement already satisfied: h11>=0.8 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.13.0)
# Requirement already satisfied: google-auth[requests]<3.0.0,>=2.48.1 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.53.0)
# Collecting httpx<1.0.0,>=0.28.1 (from google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Obtaining dependency information for httpx<1.0.0,>=0.28.1 from https://files.pythonhosted.org/packages/2a/39/e50c7c3a983047577ee07d2a9e53faf5a69493943ec3f6a384bdc792deb2/httpx-0.28.1-py3-none-any.whl.metadata
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.8.8)
# Requirement already satisfied: packaging>=23.2.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.16.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (3.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: idna>=2.8 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (48.0.0)
# Requirement already satisfied: certifi in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.4->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from cryptography>=38.0.3->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.3)
# Requirement already satisfied: pycparser in /Users/saro/Downloads/desktop june 2026/langchain/.venv/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.0)
# Downloading fastapi-0.138.0-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 5.3 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: httpx, fastapi
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.2
#     Uninstalling httpx-0.27.2:
#       Successfully uninstalled httpx-0.27.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aisuite 0.1.14 requires httpx<0.28.0,>=0.27.0, but you have httpx 0.28.1 which is incompatible.
# langchain-openai 1.2.2 requires openai<3.0.0,>=2.26.0, but you have openai 1.109.1 which is incompatible.
# Successfully installed fastapi-0.138.0 httpx-0.28.1
#
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
import os

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

response = llm.invoke(
    "Explain RAG in 3 lines."
)

print(response.content)
# Out:
# RAG (Retrieval-Augmented Generation) provides LLMs with external, up-to-date information. It first retrieves relevant data from a knowledge base based on a query. This context is then used by the LLM to generate more accurate and less hallucinatory responses.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

import os

os.environ["GOOGLE_API_KEY"] = "YOUR_API_KEY"

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

prompt = ChatPromptTemplate.from_template(
    """
    You are an AI Interview Trainer.

    Question:
    {question}

    Give concise answer.
    """
)

chain = prompt | llm

response = chain.invoke(
    {
        "question":"What is Agentic AI?"
    }
)

print(response.content)
